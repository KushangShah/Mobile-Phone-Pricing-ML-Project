# %% [markdown]
# <h1 align="center">
#   <span>Project</span>
#   <span>Name</span>
#   <span>-</span>
#   <span>Mobile</span>
#   <span>Phone</span>
#   <span>Pricing</span>
#   <span>Prediction</span>
# </h1>
#
# <style>
#     h1 {
#         text-align: center;
#         color: white;
#         padding: 50px;
#         border-radius: 12px;
#         display: inline-block;
#         background: linear-gradient(90deg, rgba(9, 17, 13, 1), rgba(11, 50, 33, 1), rgba(19, 94, 61, 1), rgba(26, 160, 109, 1));
#         background-size: 200% 200%;
#         transition: background-position 0.6s ease, transform 0.4s ease;
#         cursor: pointer;
#     }
#
#     h1 span {
#         opacity: 0.3;
#         display: inline-block;
#         transform: translateY(20px);
#         transition: opacity 0.4s ease, transform 0.4s ease;
#     }
#
#     h1:hover {
#         background-position: 100% 0;
#         transform: scale(1.05);
#     }
#
#     /* Staggered reveal effect */
#     h1:hover span {
#         opacity: 1;
#         transform: translateY(0);
#     }
#
#     h1:hover span:nth-child(1) { transition-delay: 0s; }
#     h1:hover span:nth-child(2) { transition-delay: 0.2s; }
#     h1:hover span:nth-child(3) { transition-delay: 0.4s; }
#     h1:hover span:nth-child(4) { transition-delay: 0.6s; }
#     h1:hover span:nth-child(5) { transition-delay: 0.8s; }
#     h1:hover span:nth-child(6) { transition-delay: 1.0s; }
#     h1:hover span:nth-child(7) { transition-delay: 1.2s; }
# </style>

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **Member Name -**   - Kushang Shah

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# For handling data and doing some calculations
import pandas as pd  # used for working with data in tables
import numpy as np   # helps with numbers and arrays

# For visualizing data (making graphs and charts)
import matplotlib.pyplot as plt  # used to make plots
import seaborn as sns            # makes nice-looking graphs

import random

# For some basic statistics and tests
import scipy.stats as stats
from scipy.stats import chi2_contingency  # used for checking relationships between categorical variables

# For preparing the data before training models
from sklearn.model_selection import train_test_split  # to split data into training and testing
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder  # to scale and label data
from imblearn.over_sampling import SMOTE  # helps to deal with imbalanced data

# Machine learning models (the actual algorithms)
from sklearn.linear_model import LogisticRegression  # good for binary classification
from sklearn.tree import DecisionTreeClassifier  # simple tree-based model
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier  # more advanced tree-based models


import time  # to measure how long things take

# For checking how well the models are doing
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    auc,
    precision_score,
    recall_score,
    f1_score
)

# For tuning the models to get better performance
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    StratifiedKFold,
    cross_val_score,
    learning_curve
)

# To ignore any warnings that pop up
import warnings
warnings.filterwarnings("ignore")

# To save the file
import pickle

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
mobPhone_df = pd.read_csv("dataset.csv")
df = mobPhone_df.copy()  # make a copy to work with

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()   # Dataset first 5 rows
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.tail()   # dataset last 5 row
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row, column = df.shape
print(f"Rows: {row}, Columns: {column}")
# Out:
# Rows: 2000, Columns: 21

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# Note: All the DataType os correct

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# This mean that there is no duplicated value inside the dataset

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# how many missing values are in each column
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
print()

# Let's also check what percentage of the data is missing in each column
missing_percentage = (missing_values / len(df)) * 100
print("Percentage of Missing Values:\n", round(missing_percentage, 2))
# Out:
# Missing Values:
#  battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64
#
# Percentage of Missing Values:
#  battery_power    0.0
# blue             0.0
# clock_speed      0.0
# dual_sim         0.0
# fc               0.0
# four_g           0.0
# int_memory       0.0
# m_dep            0.0
# mobile_wt        0.0
# n_cores          0.0
# pc               0.0
# px_height        0.0
# px_width         0.0
# ram              0.0
# sc_h             0.0
# sc_w             0.0
# talk_time        0.0
# three_g          0.0
# touch_screen     0.0
# wifi             0.0
# price_range      0.0
# ...

# %% [markdown]
# 0 in every columns means that there is no missing/null value inside the dataset.

# %%
# Visualizing the missing values
plt.style.use('dark_background')  # This sets black background + white text by default
sns.set_theme(style="darkgrid", rc={
    'axes.facecolor': "#0B3221",      # plot area background
    'figure.facecolor': "#09110D",    # whole figure background
    'axes.labelcolor': "white",
    'xtick.color': "white",
    'ytick.color': 'white',
    'text.color': "white",
    'axes.edgecolor': '#1AA06D',
    'grid.color': '#135E3D'
})
# 135E3D
# Calculate missing percentages
missing_percent = df.isnull().mean() * 100

# Plot it
plt.figure(figsize=(10, 6))  # making the plot
ax = missing_percent.sort_values(ascending=False).plot(kind='bar', color='#ff0800')



plt.title('Missing Values by Column')
plt.xlabel('Columns')
plt.ylabel('Percentage Missing')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# dataSet does not contain any duplicated or missing values

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# Dataset Describe
round(df.describe(), 2)
# Out:
#        battery_power    blue  clock_speed  dual_sim       fc   four_g  \
# count        2000.00  2000.0      2000.00   2000.00  2000.00  2000.00
# mean         1238.52     0.5         1.52      0.51     4.31     0.52
# std           439.42     0.5         0.82      0.50     4.34     0.50
# min           501.00     0.0         0.50      0.00     0.00     0.00
# 25%           851.75     0.0         0.70      0.00     1.00     0.00
# 50%          1226.00     0.0         1.50      1.00     3.00     1.00
# 75%          1615.25     1.0         2.20      1.00     7.00     1.00
# max          1998.00     1.0         3.00      1.00    19.00     1.00
#
#        int_memory    m_dep  mobile_wt  n_cores  ...  px_height  px_width  \
# count     2000.00  2000.00    2000.00  2000.00  ...    2000.00   2000.00
# mean        32.05     0.50     140.25     4.52  ...     645.11   1251.52
# std         18.15     0.29      35.40     2.29  ...     443.78    432.20
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# <h3 id="summary" tabindex="0" aria-label="Project summary">
#     <span class="line">- battery_power: Battery Capacity in mAh</span>
#     <span class="line">- blue: Has Bluetooth or not</span>
#     <span class="line">- clock_speed: Processor speed</span>
#     <span class="line">- dual_sim: Has dual sim support or not</span>
#     <span class="line">- fc: Front camera megapixels</span>
#     <span class="line">- four_g: Has 4G or not</span>
#     <span class="line">- int_memory: Internal Memory in GB</span>
#     <span class="line">- m_deep: Mobile depth in cm.</span>
#     <span class="line">- mobile_wt: Weight in gm</span>
#     <span class="line">- n_cores: Processor Core Count</span>
#     <span class="line">- pc: Primary Camera megapixels</span>
#     <span class="line">- px_height: Pixel Resolution height</span>
#     <span class="line">- px_width: Pixel Resolution width</span>
#     <span class="line">- ram: Ram in MB</span>
#     <span class="line">- sc_h: Mobile Screen height in cm</span>
#     <span class="line">- sc_w: Mobile Screen width in cm</span>
#     <span class="line">- talk_time: Time a single battery charge will last. In hours.</span>
#     <span class="line">- three_g: Has 3G or not</span>
#     <span class="line">- touch_screen: Has touch screen or not</span>
#     <span class="line">- wifi: Has WiFi or not</span>
#     <span class="line">- Price_range: This is the target</span>
#     <span class="line">︱0 = low cost</span>
#     <span class="line">︱1 = medium cost</span>
#     <span class="line">︱2 = high cost</span>
#     <span class="line">︱3 = very high cost</span>
# </h3>
#
# <style>
#   /* container */
#   #summary {
#     display: inline-block;
#     max-width: 950px;
#     text-align: left;
#     color: #ffffffff;
#     background: #000000ff;           /* simple, plain background */
#     border: 1px solid #000000ff;
#     padding: 20px 24px;
#     border-radius: 10px;
#     cursor: pointer;
#     line-height: 1.6;
#     font-family: system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#     font-size: 0.98rem;
#     transition: transform 0.18s ease;
#     outline: none;
#   }
#
#   /* keyboard focus visible */
#   #summary:focus {
#     box-shadow: 0 0 0 4px rgba(0,0,0,0.04);
#   }
#
#   /* each line-block */
#   .line {
#     display: block;                 /* force each span onto its own line */
#     opacity: 0.5;
#     transform: translateY(8px);
#     transition: opacity 360ms cubic-bezier(.2,.9,.2,1),
#                 transform 360ms cubic-bezier(.2,.9,.2,1);
#     margin-bottom: 0.6em;
#   }
#
#   /* reveal when hovered or focused (keyboard accessible) */
#   #summary:hover .line,
#   #summary:focus .line {
#     opacity: 1;
#     transform: translateY(0);
#   }
#
#   /* staggered delays (tweak increment to speed/slow the reveal) */
#     #summary .line:nth-of-type(1) { transition-delay: 0.00s; }
#     #summary .line:nth-of-type(2) { transition-delay: 0.06s; }
#     #summary .line:nth-of-type(3) { transition-delay: 0.12s; }
#     #summary .line:nth-of-type(4) { transition-delay: 0.18s; }
#     #summary .line:nth-of-type(5) { transition-delay: 0.24s; }
#     #summary .line:nth-of-type(6) { transition-delay: 0.30s; }
#     #summary .line:nth-of-type(7) { transition-delay: 0.36s; }
#     #summary .line:nth-of-type(8) { transition-delay: 0.42s; }
#     #summary .line:nth-of-type(9) { transition-delay: 0.48s; }
#     #summary .line:nth-of-type(10) { transition-delay: 0.54s; }
#     #summary .line:nth-of-type(11) { transition-delay: 0.60s; }
#     #summary .line:nth-of-type(12) { transition-delay: 0.66s; }
#     #summary .line:nth-of-type(13) { transition-delay: 0.72s; }
#     #summary .line:nth-of-type(14) { transition-delay: 0.78s; }
#     #summary .line:nth-of-type(15) { transition-delay: 0.84s; }
#     #summary .line:nth-of-type(16) { transition-delay: 0.90s; }
#     #summary .line:nth-of-type(17) { transition-delay: 0.96s; }
#     #summary .line:nth-of-type(18) { transition-delay: 1.02s; }
#     #summary .line:nth-of-type(19) { transition-delay: 1.08s; }
#     #summary .line:nth-of-type(20) { transition-delay: 1.14s; }
#     #summary .line:nth-of-type(21) { transition-delay: 1.20s; }
#     #summary .line:nth-of-type(22) { transition-delay: 1.26s; }
#     #summary .line:nth-of-type(23) { transition-delay: 1.32s; }
#     #summary .line:nth-of-type(24) { transition-delay: 1.38s; }
#     #summary .line:nth-of-type(25) { transition-delay: 1.44s; }
#     #summary .line:nth-of-type(26) { transition-delay: 1.50s; }
#     #summary .line:nth-of-type(27) { transition-delay: 1.56s; }
#     #summary .line:nth-of-type(28) { transition-delay: 1.62s; }
#     #summary .line:nth-of-type(29) { transition-delay: 1.68s; }
#     #summary .line:nth-of-type(30) { transition-delay: 1.74s; }
# </style>

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
    print(f"{col}: {df[col].unique()} unique values\n")
# Out:
# battery_power: [ 842 1021  563 ... 1139 1467  858] unique values
#
# blue: [0 1] unique values
#
# clock_speed: [2.2 0.5 2.5 1.2 1.7 0.6 2.9 2.8 2.1 1.  0.9 1.1 2.6 1.4 1.6 2.7 1.3 2.3
#  2.  1.8 3.  1.5 1.9 2.4 0.8 0.7] unique values
#
# dual_sim: [0 1] unique values
#
# fc: [ 1  0  2 13  3  4  5  7 11 12 16  6 15  8  9 10 18 17 14 19] unique values
#
# four_g: [0 1] unique values
#
# int_memory: [ 7 53 41 10 44 22 24  9 33 17 52 46 13 23 49 19 39 47 38  8 57 51 21  5
#  60 61  6 11 50 34 20 27 42 40 64 14 63 43 16 48 12 55 36 30 45 29 58 25
#   3 54 15 37 31 32  4 18  2 56 26 35 59 28 62] unique values
#
# m_dep: [0.6 0.7 0.9 0.8 0.1 0.5 1.  0.3 0.4 0.2] unique values
#
# mobile_wt: [188 136 145 131 141 164 139 187 174  93 182 177 159 198 185 196 121 101
#   81 156 199 114 111 132 143  96 200  88 150 107 100 157 160 119  87 152
#  166 110 118 162 127 109 102 104 148 180 128 134 144 168 155 165  80 138
#  142  90 197 172 116  85 163 178 171 103  83 140 194 146 192 106 135 153
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Dataset is ready for visualization and modeling.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# <h3 id="summary" tabindex="0" aria-label="Project summary">
#     <span class="line">DataSet have 2000 rows and 21 columns:</span>
#     <span class="line">0 duplicated rows were found in the dataset.</span>
#     <span class="line">0 missing values were found in the dataset.</span>
# </h3>
#
# <style>
#   /* container */
#   #summary {
#     display: inline-block;
#     max-width: 950px;
#     text-align: left;
#     color: #ffffffff;
#     background: #000000ff;           /* simple, plain background */
#     border: 1px solid #000000ff;
#     padding: 20px 24px;
#     border-radius: 10px;
#     cursor: pointer;
#     line-height: 1.6;
#     font-family: system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#     font-size: 0.98rem;
#     transition: transform 0.18s ease;
#     outline: none;
#   }
#
#   /* keyboard focus visible */
#   #summary:focus {
#     box-shadow: 0 0 0 4px rgba(0,0,0,0.04);
#   }
#
#   /* each line-block */
#   .line {
#     display: block;                 /* force each span onto its own line */
#     opacity: 0.5;
#     transform: translateY(8px);
#     transition: opacity 360ms cubic-bezier(.2,.9,.2,1),
#                 transform 360ms cubic-bezier(.2,.9,.2,1);
#     margin-bottom: 0.6em;
#   }
#
#   /* reveal when hovered or focused (keyboard accessible) */
#   #summary:hover .line,
#   #summary:focus .line {
#     opacity: 1;
#     transform: translateY(0);
#   }
#
#   /* staggered delays (tweak increment to speed/slow the reveal) */
#     #summary .line:nth-of-type(1) { transition-delay: 0.00s; }
#     #summary .line:nth-of-type(2) { transition-delay: 0.06s; }
#     #summary .line:nth-of-type(3) { transition-delay: 0.12s; }
# </style>

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10,6))
sns.countplot(x='price_range', data=df)
plt.title('Target Distribution: Price Range')
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,6))
sns.histplot(df['ram'], bins=20, kde=True)
plt.title('RAM Distribution')
plt.xlabel("RAM")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(10,6))
sns.histplot(df['battery_power'], bins=20, kde=True)
plt.title('Battery Power Distribution')
plt.xlabel("Battery Capacity in mAh")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10,6))
sns.histplot(df['int_memory'], bins=20, kde=True)
plt.title('Internal Memory Distribution')
plt.xlabel("Internal Memory in GB")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,6))
sns.boxplot(x='price_range', y='ram', data=df)
plt.title('RAM vs Price Range')
plt.xlabel('Price Range')
plt.ylabel('RAM')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10,6))
sns.boxplot(x='price_range', y='battery_power', data=df)
plt.title('Battery Power vs Price Range')
plt.xlabel('Price Range')
plt.ylabel('Battery Power')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
df['pixel_area'] = df['px_height'] * df['px_width']
plt.figure(figsize=(6,4))
sns.boxplot(x='price_range', y='pixel_area', data=df)
plt.title('7. Pixel Area vs Price Range')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# 8. Boxplot of Talk Time vs Price Range
plt.figure(figsize=(6,4))
sns.boxplot(x='price_range', y='talk_time', data=df)
plt.title('Talk Time vs Price Range')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# 9. Boxplot of Internal Memory vs Price Range
plt.figure(figsize=(6,4))
sns.boxplot(x='price_range', y='int_memory', data=df)
plt.title('9. Internal Memory vs Price Range')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# 10. Correlation Heatmap
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap='coolwarm', center=0)
plt.title('10. Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# 11. Scatterplot of RAM vs Pixel Area
plt.figure(figsize=(6,4))
sns.scatterplot(x='ram', y='pixel_area', hue='price_range', data=df)
plt.title('11. RAM vs Pixel Area (colored by Price Range)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# 12. Scatterplot of Battery vs Weight
plt.figure(figsize=(6,4))
sns.scatterplot(x='battery_power', y='mobile_wt', hue='price_range', data=df)
plt.title('12. Battery Power vs Mobile Weight')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# 13. Pairplot of Top Features
sns.pairplot(df[['ram','battery_power','pixel_area','int_memory','price_range']], hue='price_range')
plt.suptitle('13. Pairplot of Top Features', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# 14. Countplot of 4G by Price Range
plt.figure(figsize=(6,4))
sns.countplot(x='price_range', hue='four_g', data=df)
plt.title('14. 4G Support by Price Range')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# 15. Countplot of Touch Screen by Price Range
plt.figure(figsize=(6,4))
sns.countplot(x='price_range', hue='touch_screen', data=df)
plt.title('15. Touch Screen Support by Price Range')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# **RAM size has a significant impact on the price range of mobile phones**

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# - **Null Hypothesis (H₀)**: Mean RAM values are the same across all price ranges.
# - **Alternate Hypothesis (H₁)**: At least one price range has a significantly different mean RAM value.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Group RAM by price_range
groups = [df[df['price_range'] == i]['ram'] for i in df['price_range'].unique()]

# Perform ANOVA
f_stat, p_val = stats.f_oneway(*groups)
print("F-statistic:", f_stat)
print("P-value:", p_val)
# Out:
# F-statistic: 3520.1108238957636
# P-value: 0.0

# %% [markdown]
# Reject H₀ → RAM is highly significant in differentiating between price ranges.

# %% [markdown]
# **Business Impact**: RAM can be considered a key driver of pricing strategy. Customers perceive more RAM as higher value, so manufacturers can segment models strongly by RAM size.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# One-way ANOVA

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Because we are comparing the means of a continuous variable (RAM) across >2 independent groups (price ranges).

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# **Battery power is independent of price range.**

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# - **Null Hypothesis (H₀)**: Distribution of battery power is the same across all price ranges.
# - **Alternate Hypothesis (H₁)**: Distribution of battery power differs significantly across price ranges.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Group Battery Power by price_range
groups = [df[df['price_range'] == i]['battery_power'] for i in df['price_range'].unique()]

# Perform ANOVA
f_stat, p_val = stats.f_oneway(*groups)
print("F-statistic:", f_stat)
print("P-value:", p_val)
# Out:
# F-statistic: 31.59815753989734
# P-value: 5.948688277085545e-20

# %% [markdown]
# **Conclusion**: Reject H₀ → Battery power does differ across price ranges.

# %% [markdown]
# **Business Impact**: Battery is also a factor in pricing but not as dominant as RAM (since F-statistic is much lower). Still, emphasizing battery life in mid/high-price segments can attract buyers.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# One-way ANOVA

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Continuous variable (battery_power) vs categorical variable with >2 groups (price_range).

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Create contingency table
contingency = pd.crosstab(df['four_g'], df['price_range'])

# Perform Chi-Square Test
chi2, p_val, dof, expected = chi2_contingency(contingency)
print("Chi2 Statistic:", chi2)
print("P-value:", p_val)
# Out:
# Chi2 Statistic: 3.179879597375548
# P-value: 0.36471408196943145

# %% [markdown]
# **Conclusion**: Fail to reject H₀ → 4G support is not significantly associated with price range.

# %% [markdown]
# **Business Impact**: By the time this dataset was made, 4G had become common across all price ranges, so it no longer differentiates premium from budget models. Marketing 4G as a pricing factor won’t add value.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Chi-Square Test of Independence

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# To check association between two categorical variables.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 2. Handling Outliers

# %%
numeric_features = ['ram', 'battery_power', 'px_height', 'px_width', 'mobile_wt', 'int_memory', 'pc', 'fc']

# Set plot style
sns.set(style='whitegrid')

# Create boxplots for all numeric features
plt.figure(figsize=(16, 8))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(2, 4, i)  # 2 rows, 4 columns
    sns.boxplot(y=df[feature])
    plt.title(f'Outliers in {feature}')
plt.tight_layout()
plt.show()

# %%
# Handling Outliers & Outlier treatments

# Remove outliers in battery_power, ram, mobile_wt using Z-score (keep rows where all Z-scores < 3)
z_scores = np.abs(zscore(df[['battery_power', 'ram', 'mobile_wt']]))
df = df[(z_scores < 3).all(axis=1)]

# Remove outliers in px_height using IQR method (keep rows within [Q1 - 1.5*IQR, Q3 + 1.5*IQR])
df = df[(df['px_height'] >= Q1 - 1.5 * IQR) & (df['px_height'] <= Q3 + 1.5 * IQR)]

# Cap ram at 99th percentile to reduce effect of extreme high values
ram_99 = df['ram'].quantile(0.99)
df.loc[df['ram'] > ram_99, 'ram'] = ram_99

# Log transform px_height to reduce skewness
df['px_height_log'] = np.log1p(df['px_height'])

# %%
numeric_features = ['ram', 'battery_power', 'px_height', 'px_width', 'mobile_wt', 'int_memory', 'pc', 'fc']

# Set plot style
sns.set(style='whitegrid')

# Create boxplots for all numeric features
plt.figure(figsize=(16, 8))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(2, 4, i)  # 2 rows, 4 columns
    sns.boxplot(y=df[feature])
    plt.title(f'Outliers in {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# - **IQR Method:**
#     Used for skewed features (like fc, pc, px_height, px_width).
#     Removes values outside [Q1 - 1.5×IQR, Q3 + 1.5×IQR].
#     This helps ignore extreme values that could affect the model.
#
# - **Z-Score Method:**
#     Used for features that are roughly normal (like ram, battery_power, mobile_wt).
#     Removes values with z-score above 3 or below -3.
#     This is a standard way to spot outliers in normal data.
#
# - **Capping (Winsorization):**
#     Used for features with some very high or low values (like ram, battery_power).
#     Caps values above the 99th percentile and below the 1st percentile.
#     This keeps all rows but limits the effect of extreme values.
#
# - **Log Transformation:**
#     Used for highly skewed features (like px_height, px_width, sometimes ram).
#     Applies log1p(x) to reduce skewness.
#     This compresses large values and helps the model perform better.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
# Copy the dataset to work on
df_model = df.copy()

# Create pixel area (resolution)
df_model['pixel_area'] = df_model['px_height'] * df_model['px_width']

# Create screen area (physical size)
df_model['screen_area'] = df_model['sc_h'] * df_model['sc_w']

# Camera ratio (primary / front)
df_model['camera_ratio'] = df_model['pc'] / (df_model['fc'] + 1)  # +1 to avoid division by 0

# Drop original features that are redundant after manipulation
df_model.drop(['px_height', 'px_width', 'sc_h', 'sc_w'], axis=1, inplace=True)

# %%
df_model.head()
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 73            1038     0          1.2         0   3       0          43
# 338           1391     0          1.4         0   2       1          36
# 347            667     1          0.6         0   6       1           3
# 468            765     0          2.9         0   0       1          18
# 786            774     1          2.8         0   7       1          55
#
#      m_dep  mobile_wt  n_cores  ...   ram  talk_time  three_g  touch_screen  \
# 73     0.7        141        1  ...  3709         12        1             1
# 338    0.8        182        1  ...  3139         14        1             1
# 347    0.7        185        6  ...  2855         19        1             0
# 468    0.1        153        7  ...  1066         16        1             1
# 786    0.9        124        3  ...  3916         12        1             1
#
# ...

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
# Split features and target
X = df_model.drop('price_range', axis=1)
y = df_model['price_range']

# Train a Random Forest to get feature importance
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X, y)

# Create DataFrame of feature importances
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': rf.feature_importances_})
feature_importance.sort_values(by='Importance', ascending=False, inplace=True)

# %%
print("Feature Importances:")
print(feature_importance)

# Optional: Keep only features with importance above a threshold (e.g., >0.02)
selected_features = feature_importance[feature_importance['Importance'] > 0.02]['Feature'].tolist()
print("\nSelected Features for Modeling:")
print(selected_features)

# --- Final dataset for modeling
X_selected = X[selected_features]
# Out:
# Feature Importances:
#           Feature  Importance
# 11            ram    0.245117
# 17  px_height_log    0.106408
# 16     pixel_area    0.077457
# 8       mobile_wt    0.070648
# 7           m_dep    0.051914
# 10             pc    0.050989
# 2     clock_speed    0.050447
# 6      int_memory    0.050391
# 19   camera_ratio    0.050087
# 12      talk_time    0.043608
# 18    screen_area    0.041643
# 9         n_cores    0.041564
# 4              fc    0.036545
# 0   battery_power    0.033362
# 14   touch_screen    0.016831
# 5          four_g    0.013076
# 1            blue    0.009087
# 3        dual_sim    0.005527
# 15           wifi    0.004126
# 13        three_g    0.001173
#
# Selected Features for Modeling:
# ['ram', 'px_height_log', 'pixel_area', 'mobile_wt', 'm_dep', 'pc', 'clock_speed', 'int_memory', 'camera_ratio', 'talk_time', 'screen_area', 'n_cores', 'fc', 'battery_power']

# %%
df_model.head()
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 73            1038     0          1.2         0   3       0          43
# 338           1391     0          1.4         0   2       1          36
# 347            667     1          0.6         0   6       1           3
# 468            765     0          2.9         0   0       1          18
# 786            774     1          2.8         0   7       1          55
#
#      m_dep  mobile_wt  n_cores  ...   ram  talk_time  three_g  touch_screen  \
# 73     0.7        141        1  ...  3709         12        1             1
# 338    0.8        182        1  ...  3139         14        1             1
# 347    0.7        185        6  ...  2855         19        1             0
# 468    0.1        153        7  ...  1066         16        1             1
# 786    0.9        124        3  ...  3916         12        1             1
#
# ...

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# **Feature Manipulation**:
#
# Combines correlated features into meaningful ones: `pixel_area`, `screen_area`, `camera_ratio`.
# Drops redundant originals (px_height, px_width, sc_h, sc_w).
#
# **Feature Selection**:
#
# Uses Random Forest importance to rank features.
# Selects only features with importance above a threshold → reduces overfitting.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# RAM → strongest predictor of price (confirmed in hypothesis testing & boxplots).<br>
# Battery Power → secondary predictor.<br>
# Pixel Area (px_height * px_width) → captures display resolution, important for premium pricing.<br>
# Internal Memory (int_memory) → influences mid/high pricing.<br>
# Camera (pc, fc) → primary camera more important than front camera.<br>
# Connectivity features (four_g, wifi) → weak predictors; optional for model.<br>

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data
X_final = X_selected.copy()

# --- 1️⃣ Log Transformation for skewed features
# Identify numeric features in selected_features that are skewed
skewed_features = [f for f in X_final.columns if f in ['ram','battery_power','pixel_area','screen_area','pc','fc']]

for col in skewed_features:
    X_final[col] = np.log1p(X_final[col])  # log(1 + x) to handle zeros

# --- 2️⃣ Min-Max Scaling to normalize all features
scaler = MinMaxScaler()
X_final[skewed_features] = scaler.fit_transform(X_final[skewed_features])

# --- Now X_final is ready for modeling
print("Final dataset for modeling:")
X_final.head()
# Out:
# Final dataset for modeling:
#           ram  px_height_log  pixel_area  mobile_wt  m_dep        pc  \
# 73   0.974496       1.609438    0.796187        141    0.7  0.598104
# 338  0.904065       2.708050    0.992039        182    0.8  0.649561
# 347  0.864038       2.639057    1.000000        185    0.7  0.880939
# 468  0.448325       1.945910    0.859391        153    0.1  0.000000
# 786  0.997421       2.197225    0.900974        124    0.9  0.982878
#
#      clock_speed  int_memory  camera_ratio  talk_time  screen_area  n_cores  \
# 73           1.2          43      1.250000         12     0.000000        1
# 338          1.4          36      2.000000         14     0.877527        1
# 347          0.6           3      1.857143         19     0.000000        6
# 468          2.9          18      0.000000         16     0.474541        7
# 786          2.8          55      2.250000         12     0.419603        3
#
#            fc  battery_power
# 73   0.500000       0.464379
# ...

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data


# Identify numeric features to scale
numeric_features = ['ram', 'battery_power', 'pixel_area', 'screen_area', 'pc', 'fc']

scaler = MinMaxScaler()
X_final[numeric_features] = scaler.fit_transform(X_final[numeric_features])

print("Scaled features (first 5 rows):")
print(X_final[numeric_features].head())
# Out:
# Scaled features (first 5 rows):
#           ram  battery_power  pixel_area  screen_area        pc        fc
# 73   0.974496       0.464379    0.796187     0.000000  0.598104  0.500000
# 338  0.904065       0.718636    0.992039     0.877527  0.649561  0.396241
# 347  0.864038       0.080385    1.000000     0.000000  0.880939  0.701839
# 468  0.448325       0.199387    0.859391     0.474541  0.000000  0.000000
# 786  0.997421       0.209542    0.900974     0.419603  0.982878  0.750000

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# **why?:**
# - Features like ram, battery_power, pixel_area, screen_area, pc, and fc have different ranges.
# - Scaling ensures all features contribute equally to distance-based and gradient-based models.
#
# **method used:**
# - Min-Max Scaling → scales features to [0, 1]
# - Why: Simple, preserves relative differences, works well with log-transformed skewed data.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split dataset: 80% train, 20% test, stratified to preserve class ratios
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, random_state=42, stratify=y
)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Class distribution in y_train:\n", y_train.value_counts())
print("Class distribution in y_test:\n", y_test.value_counts())
# Out:
# X_train shape: (16, 14)
# X_test shape: (5, 14)
# Class distribution in y_train:
#  price_range
# 3    4
# 1    4
# 0    4
# 2    4
# Name: count, dtype: int64
# Class distribution in y_test:
#  price_range
# 0    2
# 3    1
# 1    1
# 2    1
# Name: count, dtype: int64

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# **split**: 80% train / 20% test
#
# - Large enough training set to learn patterns.
# - Test set sufficient to evaluate model generalization.
# - Stratification ensures all price_range classes are proportionally represented.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# Initialize and fit Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

# Predict
y_pred_rf = rf_model.predict(X_test)

# Evaluate
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy:", acc_rf)
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.8
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       1.00      1.00      1.00         1
#            2       0.50      1.00      0.67         1
#            3       1.00      1.00      1.00         1
#
#     accuracy                           0.80         5
#    macro avg       0.88      0.88      0.83         5
# weighted avg       0.90      0.80      0.80         5

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

plt.style.use('dark_background')  # This sets black background + white text by default
sns.set_theme(style="darkgrid", rc={
    'axes.facecolor': "#0B3221",      # plot area background
    'figure.facecolor': "#09110D",    # whole figure background
    'axes.labelcolor': "white",
    'xtick.color': "white",
    'ytick.color': 'white',
    'text.color': "white",
    'axes.edgecolor': '#1AA06D',
    'grid.color': '#135E3D'
})

# Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d', cmap='Greens')
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# using gridsearch CV
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid_rf = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=3, scoring='accuracy')  # cv=3 safe
grid_rf.fit(X_train, y_train)

best_rf = grid_rf.best_estimator_
y_pred_best_rf = best_rf.predict(X_test)
acc_best_rf = accuracy_score(y_test, y_pred_best_rf)
print("Tuned Random Forest Accuracy:", acc_best_rf)
# Out:
# Tuned Random Forest Accuracy: 0.8

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Using XGBClassifier

# Initialize
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
xgb_model.fit(X_train, y_train)

# Predict
y_pred_xgb = xgb_model.predict(X_test)

# Evaluate
acc_xgb = accuracy_score(y_test, y_pred_xgb)
print("XGBoost Accuracy:", acc_xgb)
print("Classification Report:\n", classification_report(y_test, y_pred_xgb))
# Out:
# XGBoost Accuracy: 0.8
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.00      0.00      0.00         1
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#
#     accuracy                           0.80         5
#    macro avg       0.67      0.75      0.70         5
# weighted avg       0.67      0.80      0.72         5

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# Hyperparameter tuning with RandomizedSearchCV
# Using RandomizedSearchCV

param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2]
}

rand_xgb = RandomizedSearchCV(XGBClassifier(eval_metric='mlogloss', use_label_encoder=False, random_state=42),
                              param_dist, n_iter=10, cv=3, scoring='accuracy', random_state=42)
rand_xgb.fit(X_train, y_train)

best_xgb = rand_xgb.best_estimator_
y_pred_best_xgb = best_xgb.predict(X_test)
acc_best_xgb = accuracy_score(y_test, y_pred_best_xgb)
print("Tuned XGBoost Accuracy:", acc_best_xgb)
# Out:
# Tuned XGBoost Accuracy: 0.8

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# Using LogisticRegression

lr_model = LogisticRegression(multi_class='multinomial', max_iter=500, random_state=42)
lr_model.fit(X_train, y_train)

y_pred_lr = lr_model.predict(X_test)
acc_lr = accuracy_score(y_test, y_pred_lr)
print("Logistic Regression Accuracy:", acc_lr)
print("Classification Report:\n", classification_report(y_test, y_pred_lr))

# Hyperparameter tuning (C parameter) with GridSearchCV
param_grid_lr = {'C':[0.01,0.1,1,10], 'solver':['lbfgs','saga']}
grid_lr = GridSearchCV(LogisticRegression(multi_class='multinomial', max_iter=500, random_state=42),
                       param_grid_lr, cv=3, scoring='accuracy')
grid_lr.fit(X_train, y_train)

best_lr = grid_lr.best_estimator_
y_pred_best_lr = best_lr.predict(X_test)
acc_best_lr = accuracy_score(y_test, y_pred_best_lr)
print("Tuned Logistic Regression Accuracy:", acc_best_lr)
# Out:
# Logistic Regression Accuracy: 0.2
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         1
#            3       0.50      1.00      0.67         1
#
#     accuracy                           0.20         5
#    macro avg       0.12      0.25      0.17         5
# weighted avg       0.10      0.20      0.13         5
#
# Tuned Logistic Regression Accuracy: 0.0

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %%
# Calculate F1-scores for each tuned model
f1_rf = f1_score(y_test, y_pred_best_rf, average='weighted')
f1_xgb = f1_score(y_test, y_pred_best_xgb, average='weighted')
f1_lr = f1_score(y_test, y_pred_best_lr, average='weighted')

# Accuracy scores
acc_rf = accuracy_score(y_test, y_pred_best_rf)
acc_xgb = accuracy_score(y_test, y_pred_best_xgb)
acc_lr = accuracy_score(y_test, y_pred_best_lr)

# plot
results = pd.DataFrame({
    'Model': ['Random Forest', 'XGBoost', 'Logistic Regression'],
    'Accuracy': [acc_rf, acc_xgb, acc_lr],
    'F1-Score': [f1_rf, f1_xgb, f1_lr]
})

# Melt for seaborn
results_melted = results.melt(id_vars='Model', value_vars=['Accuracy','F1-Score'],
                              var_name='Metric', value_name='Score')


plt.style.use('dark_background')  # This sets black background + white text by default
sns.set_theme(style="darkgrid", rc={
    'axes.facecolor': "#0B3221",      # plot area background
    'figure.facecolor': "#09110D",    # whole figure background
    'axes.labelcolor': "white",
    'xtick.color': "white",
    'ytick.color': 'white',
    'text.color': "white",
    'axes.edgecolor': '#1AA06D',
    'grid.color': '#135E3D'
})


# Plot
plt.figure(figsize=(8,5))
sns.barplot(x='Model', y='Score', hue='Metric', data=results_melted)
plt.ylim(0,1)
plt.title("Comparison of ML Models: Accuracy & F1-Score")
plt.ylabel("Score")
plt.show()

# %%
importances = best_rf.feature_importances_
features = X_final.columns

plt.figure(figsize=(10,5))
sns.barplot(x=importances, y=features, palette='viridis')
plt.title("Feature Importance - Random Forest")
plt.show()

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
# Using pickle

# Save the best Random Forest model
model_filename = 'best_random_forest_model.pkl'
with open(model_filename, 'wb') as file:
    pickle.dump(best_rf, file)

print(f"Model saved successfully as {model_filename}")
# Out:
# Model saved successfully as best_random_forest_model.pkl

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
# Load the saved model
with open(model_filename, 'rb') as file:
    loaded_model = pickle.load(file)

# Example: Predict on unseen data (can be new mobile feature rows)
# Here we just use a few rows from X_test as "unseen"
unseen_data = X_test.sample(5, random_state=random.randint(0, 100))

predictions = loaded_model.predict(unseen_data)

print("Unseen Data Predictions:")
print(predictions)
print("Corresponding Features:")
unseen_data
# Out:
# Unseen Data Predictions:
# [2 3 0 1 2]
# Corresponding Features:
#            ram  px_height_log  pixel_area  mobile_wt  m_dep        pc  \
# 1573  0.441946       2.772589    0.994073        124    0.3  0.366726
# 1481  0.972557       0.000000    0.000000         99    0.1  0.829482
# 946   0.252480       2.197225    0.932214        107    0.1  0.964830
# 1536  0.681603       1.098612    0.729317         86    0.2  0.800437
# 1146  0.811190       2.772589    0.910520        154    0.9  0.649561
#
#       clock_speed  int_memory  camera_ratio  talk_time  screen_area  n_cores  \
# 1573          1.9          43      2.000000          3     0.879446        8
# 1481          2.1          40      1.375000         16     0.000000        4
# 946           0.5          50      5.666667          8     0.743218        8
# 1536          0.6          57      1.000000         18     0.958147        3
# 1146          1.0          14      1.000000         16     0.000000        4
#
# ...

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
